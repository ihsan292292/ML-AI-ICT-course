# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r"C:\GitHub\ICT - ML&AI\Dataset\titanic.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# Group data by 'Sex to female survive
surv_by_sex= df.groupby('Sex')['Survived'].sum()
fem_surv= surv_by_sex['female']
print(fem_surv)
# Out:
# 233

# %%
# Group data by age and cabin to find number of passengers in each group
df2=df.groupby(['Sex','Survived'])['PassengerId']

# %%
import seaborn as sns

tips  = sns.load_dataset('tips')
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
tips.head()
# Relational Plot
sns.relplot(tips,x='total_bill',y='tip',style='smoker',size='size',col='time',hue='smoker')

# %%
sns.displot(tips,x='total_bill',col='time', kde=True)

# %%
#Boxplot
sns.boxplot(tips,x='day',y='total_bill')
# Out:
# <AxesSubplot: xlabel='day', ylabel='total_bill'>

# %%
# Scatter plot
sns.scatterplot(data=tips,x='total_bill',y='tip',hue='sex')
# Out:
# <AxesSubplot: xlabel='total_bill', ylabel='tip'>

# %%
sns.pairplot(data=tips)

# %% [markdown]
# Missing Values:
#
# 1.Delete or Drop
# 2.Impute:
#     - fillno.
#     - replace.

# %%
sns.violinplot(tips,x='total_bill',y='day')
# Out:
# <AxesSubplot: xlabel='total_bill', ylabel='day'>

# %%
#Syntax of Forward fill
df.fillna(method ="ffill",inplace=True)
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.isna().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          1
# Embarked       0
# dtype: int64

# %%
df['Cabin']
# Out:
# 0       NaN
# 1       C85
# 2       C85
# 3      C123
# 4      C123
#        ...
# 886     C50
# 887     B42
# 888     B42
# 889    C148
# 890    C148
# Name: Cabin, Length: 891, dtype: object

# %%
df.fillna(method='bfill',inplace=True)
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.isna().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
df.groupby('Sex').mean()
# Out:
# C:\Users\Ihsan\AppData\Local\Temp\ipykernel_20112\3123540612.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Sex').mean()
#         PassengerId  Survived    Pclass        Age     SibSp     Parch  \
# Sex
# female   431.028662  0.742038  2.159236  28.429682  0.694268  0.649682
# male     454.147314  0.188908  2.389948  30.208406  0.429809  0.235702
#
#              Fare
# Sex
# female  44.479818
# male    25.523893

# %%
df = pd.read_csv(r"C:\GitHub\ICT - ML&AI\Dataset\brain_weight.csv")
df
# Out:
#      Gender  Age Range  Head Size(cm^3)  Brain Weight(grams)
# 0         1          1             4512                 1530
# 1         1          1             3738                 1297
# 2         1          1             4261                 1335
# 3         1          1             3777                 1282
# 4         1          1             4177                 1590
# ..      ...        ...              ...                  ...
# 232       2          2             3214                 1110
# 233       2          2             3394                 1215
# 234       2          2             3233                 1104
# 235       2          2             3352                 1170
# 236       2          2             3391                 1120
#
# [237 rows x 4 columns]

# %%
df2=pd.get_dummies(df, columns=['Age Range','Gender'])
df2
# Out:
#      Head Size(cm^3)  Brain Weight(grams)  Age Range_1  Age Range_2  Gender_1  \
# 0               4512                 1530            1            0         1
# 1               3738                 1297            1            0         1
# 2               4261                 1335            1            0         1
# 3               3777                 1282            1            0         1
# 4               4177                 1590            1            0         1
# ..               ...                  ...          ...          ...       ...
# 232             3214                 1110            0            1         0
# 233             3394                 1215            0            1         0
# 234             3233                 1104            0            1         0
# 235             3352                 1170            0            1         0
# 236             3391                 1120            0            1         0
#
#      Gender_2
# 0           0
# ...

# %%
df.groupby('Age Range').mean()
df
# Out:
#      Gender  Age Range  Head Size(cm^3)  Brain Weight(grams)
# 0         1          1             4512                 1530
# 1         1          1             3738                 1297
# 2         1          1             4261                 1335
# 3         1          1             3777                 1282
# 4         1          1             4177                 1590
# ..      ...        ...              ...                  ...
# 232       2          2             3214                 1110
# 233       2          2             3394                 1215
# 234       2          2             3233                 1104
# 235       2          2             3352                 1170
# 236       2          2             3391                 1120
#
# [237 rows x 4 columns]

# %%
df2.groupby('Age Range_1').describe()
# Out:
#             Head Size(cm^3)                                                   \
#                       count         mean         std     min     25%     50%
# Age Range_1
# 0                     127.0  3598.228346  363.614967  2720.0  3361.0  3582.0
# 1                     110.0  3675.281818  364.439827  2857.0  3440.0  3641.5
#
#                             Brain Weight(grams)               ... Gender_1  \
#                 75%     max               count         mean  ...      75%
# Age Range_1                                                   ...
# 0            3850.5  4488.0               127.0  1263.937008  ...      1.0
# 1            3897.0  4747.0               110.0  1304.736364  ...      1.0
#
#                  Gender_2
#              max    count      mean       std  min  25%  50%  75%  max
# Age Range_1
# 0            1.0    127.0  0.393701  0.490505  0.0  0.0  0.0  1.0  1.0
# 1            1.0    110.0  0.481818  0.501956  0.0  0.0  0.0  1.0  1.0
#
# ...
