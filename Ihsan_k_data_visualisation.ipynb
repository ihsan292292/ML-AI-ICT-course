# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

df = pd.read_csv('/home/ihsan/Documents/GitHub/ML-AI-ICT-course/dataset/data1.csv')

df1=df
df
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        450  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# ...

# %%
#Check for null values
df.isna().sum()
# Out:
# Duration    0
# Date        1
# Pulse       0
# Maxpulse    0
# Calories    2
# dtype: int64

# %%
#Fill the null values in calories with mean values

x = df["Calories"].mean()

df["Calories"].fillna(x, inplace = True)
df
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130    409.10
# 1         60  '2020/12/02'    117       145    479.00
# 2         60  '2020/12/03'    103       135    340.00
# 3         45  '2020/12/04'    109       175    282.40
# 4         45  '2020/12/05'    117       148    406.00
# 5         60  '2020/12/06'    102       127    300.00
# 6         60  '2020/12/07'    110       136    374.00
# 7        450  '2020/12/08'    104       134    253.30
# 8         30  '2020/12/09'    109       133    195.10
# 9         60  '2020/12/10'     98       124    269.00
# 10        60  '2020/12/11'    103       147    329.30
# 11        60  '2020/12/12'    100       120    250.70
# 12        60  '2020/12/12'    100       120    250.70
# 13        60  '2020/12/13'    106       128    345.30
# 14        60  '2020/12/14'    104       132    379.30
# 15        60  '2020/12/15'     98       123    275.00
# ...

# %%
df.drop([26,6] ,axis=0, inplace=True)
df
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130    409.10
# 1         60  '2020/12/02'    117       145    479.00
# 2         60  '2020/12/03'    103       135    340.00
# 3         45  '2020/12/04'    109       175    282.40
# 4         45  '2020/12/05'    117       148    406.00
# 5         60  '2020/12/06'    102       127    300.00
# 7        450  '2020/12/08'    104       134    253.30
# 8         30  '2020/12/09'    109       133    195.10
# 9         60  '2020/12/10'     98       124    269.00
# 10        60  '2020/12/11'    103       147    329.30
# 11        60  '2020/12/12'    100       120    250.70
# 12        60  '2020/12/12'    100       120    250.70
# 13        60  '2020/12/13'    106       128    345.30
# 14        60  '2020/12/14'    104       132    379.30
# 15        60  '2020/12/15'     98       123    275.00
# 16        60  '2020/12/16'     98       120    215.20
# ...

# %%
#Convert the values in date to proper format
df['Date'] = pd.to_datetime(df['Date'])
df
# Out:
#     Duration       Date  Pulse  Maxpulse  Calories
# 0         60 2020-12-01    110       130    409.10
# 1         60 2020-12-02    117       145    479.00
# 2         60 2020-12-03    103       135    340.00
# 3         45 2020-12-04    109       175    282.40
# 4         45 2020-12-05    117       148    406.00
# 5         60 2020-12-06    102       127    300.00
# 7        450 2020-12-08    104       134    253.30
# 8         30 2020-12-09    109       133    195.10
# 9         60 2020-12-10     98       124    269.00
# 10        60 2020-12-11    103       147    329.30
# 11        60 2020-12-12    100       120    250.70
# 12        60 2020-12-12    100       120    250.70
# 13        60 2020-12-13    106       128    345.30
# 14        60 2020-12-14    104       132    379.30
# 15        60 2020-12-15     98       123    275.00
# 16        60 2020-12-16     98       120    215.20
# 17        60 2020-12-17    100       120    300.00
# ...

# %%
# Check Values in'Date' and 'Duration'.Fill appropriate values

# %%
for index, row in df.iterrows():
    if (row.Duration > 60) or (row.Duration < 30):
        df.at[index, 'Duration'] = 60
df
# Out:
#     Duration       Date  Pulse  Maxpulse  Calories
# 0         60 2020-12-01    110       130    409.10
# 1         60 2020-12-02    117       145    479.00
# 2         60 2020-12-03    103       135    340.00
# 3         45 2020-12-04    109       175    282.40
# 4         45 2020-12-05    117       148    406.00
# 5         60 2020-12-06    102       127    300.00
# 7         60 2020-12-08    104       134    253.30
# 8         30 2020-12-09    109       133    195.10
# 9         60 2020-12-10     98       124    269.00
# 10        60 2020-12-11    103       147    329.30
# 11        60 2020-12-12    100       120    250.70
# 12        60 2020-12-12    100       120    250.70
# 13        60 2020-12-13    106       128    345.30
# 14        60 2020-12-14    104       132    379.30
# 15        60 2020-12-15     98       123    275.00
# 16        60 2020-12-16     98       120    215.20
# 17        60 2020-12-17    100       120    300.00
# ...

# %%
# Fill null values in date column with appropriate value

for index, row in df.iterrows():
    if pd.isna(row.Date):
        if (index != 0) and (index != df.shape[0]-1):
            prev_date = df.at[index - 1, 'Date']
            next_date = df.at[index + 1, 'Date']
            if (prev_date + pd.Timedelta(days=2)) == next_date:
                df.at[index, 'Date'] = prev_date + pd.Timedelta(days=1)
df
# Out:
#     Duration       Date  Pulse  Maxpulse  Calories
# 0         60 2020-12-01    110       130    409.10
# 1         60 2020-12-02    117       145    479.00
# 2         60 2020-12-03    103       135    340.00
# 3         45 2020-12-04    109       175    282.40
# 4         45 2020-12-05    117       148    406.00
# 5         60 2020-12-06    102       127    300.00
# 7         60 2020-12-08    104       134    253.30
# 8         30 2020-12-09    109       133    195.10
# 9         60 2020-12-10     98       124    269.00
# 10        60 2020-12-11    103       147    329.30
# 11        60 2020-12-12    100       120    250.70
# 12        60 2020-12-12    100       120    250.70
# 13        60 2020-12-13    106       128    345.30
# 14        60 2020-12-14    104       132    379.30
# 15        60 2020-12-15     98       123    275.00
# 16        60 2020-12-16     98       120    215.20
# 17        60 2020-12-17    100       120    300.00
# ...

# %%
#Removing Duplicates
df.drop_duplicates(inplace = True)
df
# Out:
#     Duration       Date  Pulse  Maxpulse  Calories
# 0         60 2020-12-01    110       130    409.10
# 1         60 2020-12-02    117       145    479.00
# 2         60 2020-12-03    103       135    340.00
# 3         45 2020-12-04    109       175    282.40
# 4         45 2020-12-05    117       148    406.00
# 5         60 2020-12-06    102       127    300.00
# 7         60 2020-12-08    104       134    253.30
# 8         30 2020-12-09    109       133    195.10
# 9         60 2020-12-10     98       124    269.00
# 10        60 2020-12-11    103       147    329.30
# 11        60 2020-12-12    100       120    250.70
# 13        60 2020-12-13    106       128    345.30
# 14        60 2020-12-14    104       132    379.30
# 15        60 2020-12-15     98       123    275.00
# 16        60 2020-12-16     98       120    215.20
# 17        60 2020-12-17    100       120    300.00
# 18        45 2020-12-18     90       112    304.68
# ...

# %%
# Cleaned Data

df.to_csv('cleaned_data.csv')
data = df[['Duration','Pulse','Maxpulse','Calories']]
data
# Out:
#     Duration  Pulse  Maxpulse  Calories
# 0         60    110       130    409.10
# 1         60    117       145    479.00
# 2         60    103       135    340.00
# 3         45    109       175    282.40
# 4         45    117       148    406.00
# 5         60    102       127    300.00
# 7         60    104       134    253.30
# 8         30    109       133    195.10
# 9         60     98       124    269.00
# 10        60    103       147    329.30
# 11        60    100       120    250.70
# 13        60    106       128    345.30
# 14        60    104       132    379.30
# 15        60     98       123    275.00
# 16        60     98       120    215.20
# 17        60    100       120    300.00
# 18        45     90       112    304.68
# 19        60    103       123    323.00
# 20        45     97       125    243.00
# 21        60    108       131    364.20
# 22        45    100       119    282.00
# 23        60    130       101    300.00
# ...

# %%
# Graph Plotting
data.plot()
# Out:
# <Axes: >

# %%
data.plot.bar(x='Duration', y ='Calories')
# Out:
# <Axes: xlabel='Duration'>

# %%
data.plot.bar(x='Duration', y ='Maxpulse')
# Out:
# <Axes: xlabel='Duration'>

# %%
#plot 1:
x=data['Duration']
y = data['Calories']
plt.xlabel("Duration")
plt.ylabel("Calories")
plt.plot(x,y)

# %%
#plot 2:
x=data['Duration']
y = data['Maxpulse']
plt.xlabel("Duration")
plt.ylabel("Maxpulse")
plt.plot(x,y)

# %%
#plot 1:
x=data['Duration']
y = data['Pulse']
plt.xlabel("Duration")
plt.ylabel("Pulse")
plt.plot(x,y)
