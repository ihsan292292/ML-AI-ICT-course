# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv(r"C:\GitHub\ICT - ML&AI\Dataset\credit_card_default.csv")
data
# Out:
#           ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_1  PAY_2  PAY_3  \
# 0          1      20000    2          2         1   24      2      2     -1
# 1          2     120000    2          2         2   26     -1      2      0
# 2          3      90000    2          2         2   34      0      0      0
# 3          4      50000    2          2         1   37      0      0      0
# 4          5      50000    1          2         1   57     -1      0     -1
# ...      ...        ...  ...        ...       ...  ...    ...    ...    ...
# 29995  29996     220000    1          3         1   39      0      0      0
# 29996  29997     150000    1          3         2   43     -1     -1     -1
# 29997  29998      30000    1          2         2   37      4      3      2
# 29998  29999      80000    1          3         1   41      1     -1      0
# 29999  30000      50000    1          2         1   46      0      0      0
#
# ...

# %%
data.columns
# Out:
# Index(['ID', 'LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_1',
#        'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
#        'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
#        'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6',
#        'default payment next month'],
#       dtype='object')

# %%
data = data.rename(columns= lambda x:x.lower())

# %%
data = data.rename(columns={"default payment next month":"default"})

# %%
data["male"] = (data['sex'] == 1).astype(int)
data['grade_school'] = (data['education'] == 1).astype(int)
data['university'] = (data['education'] == 2).astype(int)
data['married'] = (data['marriage'] == 1).astype(int)

# %%
bill_amt_features = ["bill_amt"+ str(i) for i in range(1,7)]
pay_amt_features = ["pay_amt"+ str(i) for i in range(1,7)]
binary_features = ['male','gras_school','university','married']
payfeatures = ["pay"+ str(i) for i in range(1,7)]
